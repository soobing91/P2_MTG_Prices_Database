# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
json_file = "./AllCards.json"
mtg_df = pd.read_json(json_file)
mtg_df
# Out:
#                                                        "Ach! Hans, Run!"  \
# colorIdentity                                                     [G, R]
# colorIndicator                                                       NaN
# colors                                                            [G, R]
# convertedManaCost                                                      6
# faceConvertedManaCost                                                NaN
# foreignData                                                           []
# hand                                                                 NaN
# isReserved                                                           NaN
# layout                                                            normal
# legalities                                                            {}
# life                                                                 NaN
# loyalty                                                              NaN
# ...

# %%
mtg_df.transpose()
# Out:
#                                colorIdentity colorIndicator           colors  \
# "Ach! Hans, Run!"                     [G, R]            NaN           [G, R]
# "Rumors of My Death . . ."               [B]            NaN              [B]
# 1996 World Champion          [B, G, R, U, W]            NaN  [B, G, R, U, W]
# 2002 World Championships Ad               []            NaN               []
# A Display of My Dark Power                []            NaN               []
# A Reckoning Approaches                    []            NaN               []
# AWOL                                     [W]            NaN              [W]
# AWOL (b)                                 [W]            NaN              [W]
# Abandon Hope                             [B]            NaN              [B]
# Abandon Reason                           [R]            NaN              [R]
# Abandoned Outpost                        [W]            NaN               []
# ...

# %%
##Clean Dataframe
clean_mtg_df = mtg_df[["colors", "convertedManaCost", "text", "type"]].copy()
clean_mtg_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-0ddd9e26f6d6> in <module>
#       1 ##Clean Dataframe
# ----> 2 clean_mtg_df = mtg_df[["colors", "convertedManaCost", "text", "type"]].copy()
#       3 clean_mtg_df.head()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# ...
